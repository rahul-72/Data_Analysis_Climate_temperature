# %% [markdown]
# # GLOBAL WARNING + INDIA'S STORY

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1FXt6nIsAf50R484tFGRthlb38kERw0DF' width=1200 >

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import plotly.graph_objs as go
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))
print()
print()
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))
# Any results you write to the current directory are saved as output.
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ['GlobalLandTemperaturesByCity.csv', 'GlobalTemperatures.csv', 'GlobalLandTemperaturesByCountry.csv', 'GlobalLandTemperaturesByState.csv', 'GlobalLandTemperaturesByMajorCity.csv']
#
#
# GlobalLandTemperaturesByCity.csv
# GlobalLandTemperaturesByCountry.csv
# GlobalLandTemperaturesByMajorCity.csv
# GlobalLandTemperaturesByState.csv
# GlobalTemperatures.csv

# %%
# Let's read the dataset.
try:
    df_country = pd.read_csv('../input/GlobalLandTemperaturesByCountry.csv')
    df_state = pd.read_csv('../input/GlobalLandTemperaturesByState.csv')
    df_global = pd.read_csv('../input/GlobalTemperatures.csv')
    df_city = pd.read_csv('../input/GlobalLandTemperaturesByCity.csv')
    df_major_city = pd.read_csv('../input/GlobalLandTemperaturesByMajorCity.csv')

except Exception as e :
    pass

# %% [markdown]
# #### Let us see the top 5 entries in each dataset.

# %%
df_country.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland

# %%
df_state.head()
# Out:
#            dt  AverageTemperature   ...    State Country
# 0  1855-05-01              25.544   ...     Acre  Brazil
# 1  1855-06-01              24.228   ...     Acre  Brazil
# 2  1855-07-01              24.371   ...     Acre  Brazil
# 3  1855-08-01              25.427   ...     Acre  Brazil
# 4  1855-09-01              25.675   ...     Acre  Brazil
#
# [5 rows x 5 columns]

# %%
df_city.head()
# Out:
#            dt  AverageTemperature    ...     Latitude Longitude
# 0  1743-11-01               6.068    ...       57.05N    10.33E
# 1  1743-12-01                 NaN    ...       57.05N    10.33E
# 2  1744-01-01                 NaN    ...       57.05N    10.33E
# 3  1744-02-01                 NaN    ...       57.05N    10.33E
# 4  1744-03-01                 NaN    ...       57.05N    10.33E
#
# [5 rows x 7 columns]

# %%
df_global.head()
# Out:
#            dt                    ...                      LandAndOceanAverageTemperatureUncertainty
# 0  1750-01-01                    ...                                                            NaN
# 1  1750-02-01                    ...                                                            NaN
# 2  1750-03-01                    ...                                                            NaN
# 3  1750-04-01                    ...                                                            NaN
# 4  1750-05-01                    ...                                                            NaN
#
# [5 rows x 9 columns]

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# # WORLD ANALYSIS

# %% [markdown]
# ### Q1). Land Temperature trend of World over years.

# %%
df_global['year'] = pd.to_datetime(df_global['dt']).dt.year
by_year = df_global.groupby('year')['LandAverageTemperature'].mean().reset_index()
by_year.iplot(kind='scatter', x='year', y='LandAverageTemperature', title='Temperature trend',
              xTitle='Year', yTitle='Temperature')
# Out:
# <div>
#
#
#             <div id="af836540-1b23-485d-b01b-e59e025895cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("af836540-1b23-485d-b01b-e59e025895cf")) {
#                     Plotly.newPlot(
#                         'af836540-1b23-485d-b01b-e59e025895cf',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "LandAverageTemperature", "text": "", "type": "scatter", "uid": "3438781b-6b61-4a35-8492-5e70758854c7", "x": [1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], "y": [8.719363636363637, 7.9761428571428565, 5.7798333333333325, 8.388083333333332, 8.469333333333335, 8.355583333333334, 8.849583333333333, 9.022, 6.743583333333333, 7.985083333333333, 7.185166666666667, 8.772499999999999, 8.6065, 7.496749999999999, 8.400333333333332, 8.251916666666666, 8.405666666666667, 8.221499999999999, 6.781333333333333, 7.694583333333334, 7.691916666666667, 7.8531666666666675, 8.1935, 8.2215, 8.772166666666665, 9.183083333333334, 8.304, 8.256250000000001, 8.54225, 8.98325, 9.432916666666667, 8.102583333333332, 7.901249999999998, 7.680833333333333, 7.862000000000001, 7.3629999999999995, 8.258166666666666, 8.031833333333333, 8.447166666666666, 8.334166666666667, 7.982333333333333, 8.23425, 8.089, 8.229166666666666, 8.526000000000002, 8.350333333333333, 8.270999999999999, 8.510583333333335, 8.67025, 8.505749999999999, 8.484250000000001, 8.589666666666668, 8.578166666666666, 8.503, 8.844833333333334, 8.56275, 8.434083333333332, 8.281416666666665, 7.626833333333333, 7.076416666666667, 6.922666666666665, 6.859500000000001, 7.046250000000001, 7.7399166666666686, 7.59175, 7.239333333333334, 6.9375, 6.975666666666668, 7.828916666666667, 7.3691666666666675, 7.616249999999998, 8.090083333333332, 8.188333333333334, 7.7186666666666675, 8.547166666666667, 8.389333333333333, 8.356583333333335, 8.808749999999998, 8.165333333333335, 7.941833333333332, 8.51675, 7.639166666666667, 7.450166666666667, 8.013, 8.14675, 7.392499999999999, 7.695833333333334, 7.375666666666665, 7.514916666666665, 7.632249999999999, 7.796250000000001, 7.688166666666667, 8.02275, 8.173666666666666, 7.646333333333334, 7.851166666666668, 8.55275, 8.086, 7.979500000000001, 7.984416666666667, 7.900666666666666, 8.178583333333332, 8.100166666666665, 8.041833333333333, 8.2105, 8.110749999999998, 7.995916666666666, 7.758166666666668, 8.10025, 8.252, 7.960833333333333, 7.846500000000002, 7.558583333333334, 8.111833333333333, 7.983583333333335, 8.177833333333334, 8.292166666666665, 8.436333333333334, 8.247916666666667, 8.432083333333333, 8.201333333333332, 8.115083333333333, 8.193833333333332, 8.351083333333333, 8.4335, 7.859583333333334, ...
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Temperature trend"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Year"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Temperature"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('af836540-1b23-485d-b01b-e59e025895cf');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed

# %% [markdown]
# #### Observations:-
# * Global temperature in the initial years was altering on both side, as it was rising in some years and it was as also decrreasing in some years.
# * But after 1950 the global temperature is rising very fast, as increament in 1 degree effects very much.
# * The time has been come to concern about it.
# * If it follows the same trend then 30 years after 2000 the temperature will rise 1 degree, which is a matter of concern.

# %% [markdown]
# #### ==================================================================================================

# %% [markdown]
# ### Q2).Top 10 hottest countries.

# %%
hot_country = df_country.groupby('Country')['AverageTemperature'].mean().reset_index()
hot_country.sort_values('AverageTemperature', ascending=False, inplace=True)
hot_country.reset_index(drop=True, inplace=True)
hot_country = hot_country[:10]


code = ['DJI', 'ML','BFA','SEN','ABW','ARE','MRT','GMB','NER','CUW']
country = hot_country['Country']
temp = hot_country['AverageTemperature']

data = dict(
type = 'choropleth',
locations = code,
z = temp,
text = country,
colorbar = {'title' : 'Temperature'},
)

layout = dict(
title = 'Top 10 hottest Countries',
geo = dict(
showframe = False,
projection = {'type':'natural earth'}
)
)

choromap = go.Figure(data = [data],layout = layout)
iplot(choromap)

hot_country.T
# Out:
# <div>
#
#
#             <div id="189b70b0-6b37-4a79-b0cd-30ecc97ed233" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("189b70b0-6b37-4a79-b0cd-30ecc97ed233")) {
#                     Plotly.newPlot(
#                         '189b70b0-6b37-4a79-b0cd-30ecc97ed233',
#                         [{"colorbar": {"title": {"text": "Temperature"}}, "locations": ["DJI", "ML", "BFA", "SEN", "ABW", "ARE", "MRT", "GMB", "NER", "CUW"], "text": ["Djibouti", "Mali", "Burkina Faso", "Senegal", "Aruba", "United Arab Emirates", "Mauritania", "Gambia", "Niger", "Cura\u00e7ao"], "type": "choropleth", "uid": "1626192c-4ce6-4ce6-85e2-3daf6cd75a42", "z": [28.816602533172542, 28.441976570819996, 28.083506760410998, 27.96737499999997, 27.92039022051774, 27.693994700582884, 27.620255504352293, 27.538551816239316, 27.458972540045757, 27.353414669223397]}],
#                         {"geo": {"projection": {"type": "natural earth"}, "showframe": false}, "title": {"text": "Top 10 hottest Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('189b70b0-6b37-4a79-b0cd-30ecc97ed233');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
#                            0       1   ...          8        9
# Country             Djibouti    Mali   ...      Niger  Curaçao
# AverageTemperature   28.8166  28.442   ...     27.459  27.3534
#
# [2 rows x 10 columns]

# %% [markdown]
# #### ==================================================================================================

# %% [markdown]
# ### Q3). Top 10 Coolest Countries.

# %%
cool_country = df_country.groupby('Country')['AverageTemperature'].mean().reset_index()
cool_country.sort_values('AverageTemperature', inplace=True)
cool_country.reset_index(drop=True, inplace=True)
cool_country = cool_country[:10]


code = ['GRL','DNK','SJM','RUS','CAN','MNG','NOR','FIN','SGS','ISL']
country = cool_country['Country']
temp = cool_country['AverageTemperature']

data = dict(
type = 'choropleth',
locations = code,
z = temp,
text = country,
colorbar = {'title' : 'Temperature'},
)

layout = dict(
title = 'Top 10 Coolest Countries',
geo = dict(
showframe = False,
projection = {'type':'natural earth'}
)
)

choromap = go.Figure(data = [data],layout = layout)
iplot(choromap)

cool_country.T
# Out:
# <div>
#
#
#             <div id="5755fd9a-7f8f-41d4-b627-a520590f3d19" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5755fd9a-7f8f-41d4-b627-a520590f3d19")) {
#                     Plotly.newPlot(
#                         '5755fd9a-7f8f-41d4-b627-a520590f3d19',
#                         [{"colorbar": {"title": {"text": "Temperature"}}, "locations": ["GRL", "DNK", "SJM", "RUS", "CAN", "MNG", "NOR", "FIN", "SGS", "ISL"], "text": ["Greenland", "Denmark", "Svalbard And Jan Mayen", "Russia", "Canada", "Mongolia", "Norway", "Finland", "South Georgia And The South Sandwich Isla", "Iceland"], "type": "choropleth", "uid": "9bd58fc6-f95b-4aa0-8600-71bee55f4c66", "z": [-18.58745804195801, -18.053050699300716, -7.448027925531907, -5.521881912681911, -5.216658945686897, -0.8206709844559608, 0.09580385344283023, 1.2447422615287405, 1.4010251017639086, 1.4050650663297544]}],
#                         {"geo": {"projection": {"type": "natural earth"}, "showframe": false}, "title": {"text": "Top 10 Coolest Countries"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('5755fd9a-7f8f-41d4-b627-a520590f3d19');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
#                             0   ...           9
# Country             Greenland   ...     Iceland
# AverageTemperature   -18.5875   ...     1.40507
#
# [2 rows x 10 columns]

# %% [markdown]
# #### ==================================================================================================

# %% [markdown]
# ### Q4). Temperature trend in top 5 ecomonic Countries.

# %%
country_top = ['India','United States','China','Japan','Russia']
new_df = df_country[df_country['Country'].isin(country_top)]
#print(new_df['Country'].unique())

new_df['year'] = pd.to_datetime(new_df['dt']).dt.year

new_df = new_df.groupby(['Country','year'])['AverageTemperature'].mean().reset_index()
new_df

new_pivot = new_df.pivot_table(values='AverageTemperature', index='year', columns='Country')
new_pivot.iplot(kind='scatter', title='Temperature trend in Top 5 Economic Countries.',
                xTitle='Year', yTitle='Temperature')
# Out:
# <div>
#
#
#             <div id="e34eb5f6-d9b0-47f6-b016-0cd9be0b5f78" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e34eb5f6-d9b0-47f6-b016-0cd9be0b5f78")) {
#                     Plotly.newPlot(
#                         'e34eb5f6-d9b0-47f6-b016-0cd9be0b5f78',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "China", "text": "", "type": "scatter", "uid": "8c0959e3-999d-4cdb-a0ce-dbedf31f07e6", "x": [1768, 1769, 1774, 1775, 1776, 1777, 1778, 1779, 1781, 1782, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], "y": ["", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", 5.013599999999999, 6.284166666666667, 6.3414166666666665, 7.024363636363637, "", "", "", "", "", "", "", "", "", 6.039333333333335, 6.268166666666667, 5.43425, 5.364727272727273, 8.136833333333332, 5.715, 5.5190833333333345, 6.018583333333333, 5.512416666666667, 6.2785, 6.413916666666668, 6.051500000000001, 6.023000000000001, 6.587500000000001, 6.257083333333333, 5.939749999999999, 6.104833333333335, 5.907166666666666, 5.7828333333333335, 5.857500000000001, 5.997583333333334, 6.473083333333334, 6.515583333333335, 6.095583333333334, 5.959666666666668, 6.414083333333334, 6.535166666666669, 5.609333333333332, 5.865166666666667, 5.448083333333333, 6.444583333333333, 5.8015, 6.243999999999999, 6.410416666666667, 6.759166666666666, 6.415499999999999, 6.465833333333332, 6.158999999999999, 6.371583333333334, 6.286333333333332, 6.588166666666666, 6.645166666666667, 6.505, 6.347416666666667, 6.181583333333332, 6.414416666666668, 6.667416666666667, 6.383500000000001, 6.352833333333334, 6.398250000000001, 6.026916666666668, 5.804833333333332, 5.964500000000001, 6.114750000000001, 6.197166666666668, 6.336416666666665, 6.31175, 6.464333333333333, 6.359333333333335, 6.060833333333334, 6.108333333333333, 6.578250000000001, 6.035833333333334, 6.386250000000001, 6.228083333333331, 6.562666666666666, 6.603416666666667, 6.444166666666668, 6.537499999999999, 6.744666666666666, 6.1745833333333335, 6.350833333333334, 5.755499999999999, 6.2218333333333335, 6.308666666666667, 6.286583333333335, 6.381249999999999, 6.0715, 6.297, 6.076083333333332, 6.138416666666665, 6.818749999999999, 6.49275, 6.349833333333334, 6.161416666666668, 6.196833333333334, 6.607, 6.5903333333333345, 6.500750000000001, 6.6773333333333325, 6.563666666666666, 6.704250000000001, 6.5556666666666645, 6.754083333333334, 6.667749999999999, 6.7746666666666675, 6.424083333333333, 6.468666666666667, 6.3775, 6.905583333333333, 6.6299166666666665, 6.362833333333332, 6.636166666666668, 6.111583333333335, 6.511083333333332, 6.87175, 7.026500000000001, 6.961666666666665, 7.345499999999999, 7.096, 7.050916666666666, 6.530500000000001, 6.838833333333334, 7.354083333333334, 6.773833333333333, 7.100333333333334, 6.9755, 6.641166666666666, 6.869500000000002, 6.640916666666667, 7.022333333333335, 6.37099999999 ...

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q5). Top 10 States with highest average temperature and their temperature trend over years.

# %%
states = df_state.groupby(['State','Country'])['AverageTemperature'].mean().reset_index()
states.sort_values('AverageTemperature',inplace=True, ascending=False)
print(states[:10])

name_states = states['State'][:10]
name_states

temp_df = df_state[df_state['State'].isin(name_states)]
temp_df['year'] = pd.to_datetime(temp_df['dt']).dt.year
state_pivot = temp_df.pivot_table(values='AverageTemperature', index='year', columns='State')
state_pivot.iplot(kind='scatter', title='Temperature trend of top 10 states', 
                  xTitle='Year', yTitle='Temperature')
# Out:
#                    State Country  AverageTemperature
# 168           Puducherry   India           27.266897
# 10   Andaman And Nicobar   India           27.231677
# 11        Andhra Pradesh   India           27.090003
# 175  Rio Grande Do Norte  Brazil           27.011470
# 200           Tamil Nadu   India           26.667812
# 90                Kerala   India           26.319626
# 57               Gujarat   India           26.296188
# 42         Daman And Diu   India           26.274003
# 8               Amazonas  Brazil           26.132262
# 109          Maharashtra   India           25.933388
# <div>
#
#
#             <div id="9d7bd4ae-17aa-4e99-be93-473a45f0e67d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9d7bd4ae-17aa-4e99-be93-473a45f0e67d")) {
#                     Plotly.newPlot(
#                         '9d7bd4ae-17aa-4e99-be93-473a45f0e67d',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Amazonas", "text": "", "type": "scatter", "uid": "8b0697b2-25fc-4ef2-9bca-7d8a388bb063", "x": [1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], "y": ["", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", 25.535, 26.187916666666666, 25.57258333333333, 25.540833333333335, 25.58566666666667, 25.56125, 25.700250000000008, 25.660666666666668, 25.664749999999998, 25.731416666666664, 25.788000000000007, 25.43925, 25.23941666666666, 25.617166666666662, 25.835833333333337, 25.67625, 25.408555555555555, 25.360272727272733, 25.657750000000004, 25.59725, 25.718499999999995, 25.800083333333333, 25.99266666666667, 25.76158333333333, 26.080416666666665, 25.72316666666667, 25.744666666666664, 25.76041666666667, 26.106166666666667, 25.873500000000003, 25.352333333333334, 25.694750000000003, 26.229916666666668, 26.459750000000003, 25.666166666666673, 25.495333333333335, 25.941416666666665, 25.579333333333334, 25.5, 25.374666666666666, 25.01275, 25.37275, 25.53183333333334, 25.76166666666667, 25.936000000000003, 25.343666666666667, 25.58875, 25.483750000000004, 25.382833333333334, 25.601416666666665, 25.870333333333335, 25.99416666666666, 25.911666666666672, 25.544749999999997, 25.852666666666668, 26.274583333333336, 26.247416666666666, 26.006, 25.882083333333338, 25.641833333333334, 26.158333333333342, 25.9015, 25.643583333333336, 25.63841666666667, 25.730333333333334, 25.588166666666666, 25.754333333333335, 26.065749999999998, 25.877333333333336, 26.248833333333334, 26.349166666666665, 25.78916666666667, 25.27316666666667, 25.729749999999996, 26.150916666666664, 25.842, 25.667833333333338, 25.752916666666668, 25.71141666666667, 25.94425, 25.935000000000002, 26.444083333333335, 25.960833333333337, 26.226250000000004, 25.97758333333334, 26.09166666666667, 26.207083333333333, 26.101250000000004, 26.0745, 25.97758333333334, 26.193833333333334, 26.40216666666667, 26.611083333333337, 26.173833333333334, 26.261, 26.690250000000002, 26.
333333332, 23.74191666666667, 23.661, 23.544166666666666, 23.869333333333334, 24.007083333333338, 23.700833333333332, 23.8255, 24.29008333333333, 23.825499999999995, 23.08108333333334, 23.771749999999997, 23.82516666666667, 23.955416666666668, 24.249250000000004, 23.904416666666663, 23.90925, 24.046000000000003, 23.662583333333334, 23.847333333333328, 23.773749999999996, 24.139, 23.971416666666666, 23.837, 24.24933333333333, 24.07858333333333, 23.560333333333332, 23.767416666666673, 23.76183333333334, 23.83483333333334, 23.707916666666673, 23.891916666666663, 23.99325, 23 ...
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Temperature trend in India"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Year"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Temperature"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('de1b970c-8f72-4a89-a267-385097ff9e85');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q7). Top 10 India's Coolest States.

# %%
state = df_state[df_state['Country']=='India']
state = state.groupby('State')['AverageTemperature'].mean().reset_index()
state.sort_values('AverageTemperature',inplace=True, )
state = state[:10]
state.iplot(kind='bar', x='State', y='AverageTemperature', title='Top 10 Coolest States',
           xTitle='State', yTitle='Temperature', color='deepskyblue')
# Out:
# <div>
#
#
#             <div id="15868685-8bc2-45e0-98ca-bcadcf00c232" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("15868685-8bc2-45e0-98ca-bcadcf00c232")) {
#                     Plotly.newPlot(
#                         '15868685-8bc2-45e0-98ca-bcadcf00c232',
#                         [{"marker": {"color": "rgba(0, 191, 255, 0.6)", "line": {"color": "rgba(0, 191, 255, 1.0)", "width": 1}}, "name": "AverageTemperature", "orientation": "v", "text": "", "type": "bar", "uid": "a37117c8-da69-4401-9d09-cfb79767bac5", "x": ["Sikkim", "Jammu And Kashmir", "Himachal Pradesh", "Chandigarh", "Arunachal Pradesh", "Uttaranchal", "Manipur", "Nagaland", "Assam", "Mizoram"], "y": [3.1491010873942775, 3.2040616929698738, 9.09824116222761, 13.381667312348657, 13.79566996848266, 14.697140740740746, 21.18668366890375, 21.39875933423301, 21.875561316501326, 23.31538814229251]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Coolest States"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "State"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Temperature"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('15868685-8bc2-45e0-98ca-bcadcf00c232');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### ===================================================================================================

# %% [markdown]
# ### Q8). Top 10 Hotest States.

# %%
state = df_state[df_state['Country']=='India']
state = state.groupby('State')['AverageTemperature'].mean().reset_index()
state.sort_values('AverageTemperature',inplace=True, ascending=False)
state = state[:10]
state.iplot(kind='bar', x='State', y='AverageTemperature', title='Top 10 Hotest States',
           xTitle='State', yTitle='Temperature')
# Out:
# <div>
#
#
#             <div id="f09b20b1-4fef-43c9-b109-6f7b9d790579" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f09b20b1-4fef-43c9-b109-6f7b9d790579")) {
#                     Plotly.newPlot(
#                         'f09b20b1-4fef-43c9-b109-6f7b9d790579',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "AverageTemperature", "orientation": "v", "text": "", "type": "bar", "uid": "ffaffc8e-bb13-4062-ac6d-e7908bcdcf10", "x": ["Puducherry", "Andaman And Nicobar", "Andhra Pradesh", "Tamil Nadu", "Kerala", "Gujarat", "Daman And Diu", "Maharashtra", "Orissa", "Goa"], "y": [27.266897129186614, 27.23167733017375, 27.090002791068628, 26.667812200956945, 26.319626409017708, 26.296187706270622, 26.274002818035434, 25.93338755980857, 25.927605055292222, 25.755925039872416]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "showlegend": true, "title": {"font": {"color": "#4D5663"}, "text": "Temperature trend of Jodhpur City in India"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Year"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Temperature"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('7e3d3cbd-8af6-4a0d-ace6-853fefd2fb18');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### ==================================================================================================

# %% [markdown]
# ### Q10). Average Temperature of major Indian Cities.

# %%
new_df = df_major_city[df_major_city['Country']=='India']
new_df['year'] = pd.to_datetime( new_df['dt']).dt.year # Converting date into year and making new column.

by_new = new_df.groupby(['City','year'] )['AverageTemperature'].mean().reset_index()
new_pivot = by_new.pivot_table(values='AverageTemperature', index='year', columns='City')
new_pivot.iplot(kind='scatter')
# Out:
# <div>
#
#
#             <div id="8c7e16ce-a3e4-41b5-947d-bf0a4db7e9de" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8c7e16ce-a3e4-41b5-947d-bf0a4db7e9de")) {
#                     Plotly.newPlot(
#                         '8c7e16ce-a3e4-41b5-947d-bf0a4db7e9de',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Ahmadabad", "text": "", "type": "scatter", "uid": "f4aefee0-74bf-49df-b060-7eefec493874", "x": [1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], "y": [26.350916666666667, 27.4531, 25.8176, 26.616000000000003, 26.560833333333335, 25.7303, 27.01, 26.76675, 27.0925, 26.665666666666667, 26.574750000000005, 26.099700000000002, 25.917833333333334, 25.256545454545456, 25.449583333333333, 25.014916666666664, 25.22758333333333, 25.78391666666667, 25.35925, 25.52208333333333, 26.14708333333333, 26.202083333333334, 26.032083333333333, 26.676083333333334, 26.45566666666667, 26.49116666666667, 26.652666666666672, 26.264250000000004, 26.078666666666667, 26.367, 25.8415, 25.993900000000004, 26.18366666666667, 26.221, 25.36491666666667, 25.851833333333335, 25.75675, 25.77866666666667, 25.885166666666667, 26.005749999999995, 25.77983333333333, 26.126083333333337, 25.97775, 25.737583333333333, 25.993666666666666, 26.59008333333334, 26.033416666666664, 25.955666666666673, 25.918750000000006, 26.082333333333334, 26.073999999999998, 26.07108333333333, 26.236166666666666, 26.371750000000006, 26.412909090909093, 25.355909090909094, 25.640583333333336, "", "", "", "", "", "", "", 27.774888888888892, 26.396666666666672, 26.715, 26.005272727272725, 26.523416666666666, 26.213583333333332, 26.203833333333332, 26.222166666666666, 26.336916666666664, 26.358833333333337, 26.509083333333336, 26.423166666666663, 26.660750000000004, 26.735833333333336, 26.150583333333334, 26.565750000000005, 26.331333333333333, 26.249750000000006, 25.8445, 25.764083333333332, 25.96241666666667, 26.342333333333332, 26.0625, 26.128416666666666, 26.521750000000008, 26.412416666666672, 26.318500000000004, 26.69616666666667, 25.452916666666663, 26.02825, 26.49716666666667, 26.991416666666666, 26.5535, 26.937583333333333, 27.07066666666667, 26.902666666666672, 26.831500000000002, 27.295833333333334, 26.276, 26.622250000000005, 26.236166666666666, 26.18908333333334, 26.363333333333333, 26.071166666666667, 26.049083333333332, 26.08725, 26.59975, 26.888083333333338, 26.439333333333337, 26.561000000000003, 27.005333333333336, 26.49775, 25.595166666666668, 26.474999999999998, 26.391666666666666, 26.65258333333333, 27.051583333333337, 26.426750000000002, 26.444833333333335, 26.633749999999996, 26.664833333333334, 26.551, 26.076249999999998, 26.600583333333343, 26.75766666666667, 26.581500000000005, 26.948916666666673, 26.9045, 26.290666666666667, 26.3475, 26.09716666666667, 26.361749999999997, 26.237083333333334, 26.45975, 26.612750000000005, 26.54450000000001, 27.23391666666667, 26.71341666666667, 26.687666666666672, 26.47266666666667,  ...

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q11). Average Temperature of India's major Cities by Month on Heatmap.

# %%
city = df_major_city[df_major_city['Country']=='India']
city['month'] = pd.to_datetime(city['dt']).dt.month
city['month'] = city['month'].map({1:'January', 2:'Februay', 3:'March',4:'April', 5:'May', 6:'June', 
                                  7:'July', 8:'August', 9:'September', 10:'October', 11:'November', 12:'December'})
city_pivot = city.pivot_table(values='AverageTemperature', index='month', columns='City')
city_pivot.iplot(kind='heatmap',colorscale= 'YlOrRd')
# Out:
# <div>
#
#
#             <div id="9786965d-aa5e-4513-885c-2e28b8a34e96" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9786965d-aa5e-4513-885c-2e28b8a34e96")) {
#                     Plotly.newPlot(
#                         '9786965d-aa5e-4513-885c-2e28b8a34e96',
#                         [{"colorscale": [[0.0, "rgb(255,255,204)"], [0.125, "rgb(255,237,160)"], [0.25, "rgb(254,217,118)"], [0.375, "rgb(254,178,76)"], [0.5, "rgb(253,141,60)"], [0.625, "rgb(252,78,42)"], [0.75, "rgb(227,26,28)"], [0.875, "rgb(189,0,38)"], [1.0, "rgb(128,0,38)"]], "type": "heatmap", "uid": "41c6c717-0454-431f-9b2a-81f46e29d271", "x": ["April", "August", "December", "Februay", "January", "July", "June", "March", "May", "November", "October", "September"], "y": ["Ahmadabad", "Bangalore", "Bombay", "Calcutta", "Delhi", "Hyderabad", "Jaipur", "Kanpur", "Lakhnau", "Madras", "Nagpur", "New Delhi", "Pune", "Surat"], "z": [[30.54404975124379, 27.38673300970874, 20.46971078431372, 21.661029556650245, 19.41185294117648, 28.713665048543692, 31.729424390243906, 26.430074257425737, 32.93900000000001, 24.089258536585366, 27.27933658536586, 27.748141463414637], [27.98851690821257, 24.362909523809517, 22.29085576923078, 24.656619047619056, 22.713980952380954, 24.40048095238094, 25.468799043062212, 27.062185714285704, 27.52275362318839, 23.265157894736852, 24.09178468899521, 24.495114832535872], [27.413801932367146, 26.61944761904763, 25.574889423076918, 24.039885714285727, 24.19209523809525, 27.078728571428556, 28.271755980861236, 25.673476190476183, 28.90256521739129, 27.306114832535897, 27.69363157894736, 26.861770334928227], [29.847133971291882, 28.809150943396208, 19.156114285714285, 21.5039858490566, 18.53433490566037, 28.995377358490565, 29.920981042654024, 26.596806603773597, 30.5862870813397, 23.160976303317533, 26.874407582938392, 28.59412322274881], [29.004575757575754, 29.75242288557213, 15.378814070351764, 17.144979999999997, 14.238560000000001, 31.174114427860694, 33.866005, 23.0148040201005, 33.29705102040816, 20.34651000000001, 25.86637500000001, 28.994464999
   'line': {'color': 'rgb(40,40,40)', 'width': 0.5},
   'size': 5,
   'sizemode': 'diameter',
    'colorbar': dict(
            title = 'Temperature', 
            thickness = 10,           
            outlinecolor = "rgba(68, 68, 68, 0)",            
            ticklen = 3,                       
            dtick = 0.1      )        },
  'text': name.astype(str) + '  ->  ' ,
  'type': 'scattergeo',
  
      }]


layout = go.Layout(
    title = 'Average Temperature of Major Cities of India',
    showlegend = True,
    geo = dict(
            scope='asia',
            projection=dict( type = 'natural earth'),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),)

fig =  go.Figure(layout=layout, data=data)
iplot( fig, validate=False)
# Out:
# <div>
#
#
#             <div id="36f971e9-3f91-4c09-8a73-dd0f41b89e4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("36f971e9-3f91-4c09-8a73-dd0f41b89e4f")) {
#                     Plotly.newPlot(
#                         '36f971e9-3f91-4c09-8a73-dd0f41b89e4f',
#                         [{"lat": [23.0225, 12.9716, 19.076, 22.5726, 28.7041, 17.385, 26.9124, 26.4499, 26.8467, 13.0827, 21.1458, 28.6139, 18.5204, 21.1702], "lon": [72.5714, 77.5946, 72.8777, 88.3639, 77.1025, 78.4867, 75.7873, 80.3319, 80.9462, 80.2707, 79.0882, 77.209, 73.8567, 72.8311], "marker": {"color": [26.52985294117645, 24.855895933014338, 26.63145215311006, 26.042152053712506, 25.1658609022556, 26.869334928229648, 25.39305794080872, 24.760040783034253, 24.760040783034253, 28.417858452950554, 25.65501634768742, 25.1658609022556, 24.64461523125997, 26.330856459330157], "colorbar": {"dtick": 0.1, "outlinecolor": "rgba(68, 68, 68, 0)", "thickness": 10, "ticklen": 3, "title": {"text": "Temperature"}}, "line": {"color": "rgb(40,40,40)", "width": 0.5}, "size": 5, "sizemode": "diameter"}, "text": ["Ahmadabad  ->  ", "Bangalore  ->  ", "Bombay  ->  ", "Calcutta  ->  ", "Delhi  ->  ", "Hyderabad  ->  ", "Jaipur  ->  ", "Kanpur  ->  ", "Lakhnau  ->  ", "Madras  ->  ", "Nagpur  ->  ", "New Delhi  ->  ", "Pune  ->  ", "Surat  ->  "], "type": "scattergeo", "uid": "69d2a5c8-96c6-4722-9798-a29325dd29db"}],
#                         {"geo": {"countrycolor": "rgb(255, 255, 255)", "countrywidth": 1, "landcolor": "rgb(217, 217, 217)", "projection": {"type": "natural earth"}, "scope": "asia", "showland": true, "subunitcolor": "rgb(255, 255, 255)", "subunitwidth": 1}, "showlegend": true, "title": {"text": "Average Temperature of Major Cities of India"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('36f971e9-3f91-4c09-8a73-dd0f41b89e4f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1p9RaaYWgcVMRJfk3d5exTO1xwxDP6C0G' width=700>

# %% [markdown]
# #### =====================================================================================================
# #### =====================================================================================================
# #### =====================================================================================================

# %% [markdown]
# # IF THIS KERNEL IS HELPFUL, THEN PLEASE UPVOTE.
# <img src='https://drive.google.com/uc?id=1MZ0IY99BTBz0TbaGR1ZT0OuZ9aLS_QV-' width=500>
